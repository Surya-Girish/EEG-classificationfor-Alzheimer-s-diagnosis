# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, make_scorer
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics

# %%
df=pd.read_csv('ColumnFinal1.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
lr= LogisticRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))

x1=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x1.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores1 = cross_val_score(lr, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores1)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)))
# Out:
# accuracy 0.708029197080292
# Precision 0.7
# Recall 0.7205882352941176
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.60      0.66      0.63        32
#            1       0.62      0.56      0.59        32
#
#     accuracy                           0.61        64
#    macro avg       0.61      0.61      0.61        64
# weighted avg       0.61      0.61      0.61        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72        32
#            1       0.72      0.72      0.72        32
#
#     accuracy                           0.72        64
#    macro avg       0.72      0.72      0.72        64
# weighted avg       0.72      0.72      0.72        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        32
#            1       0.75      0.75      0.75        32
#
#     accuracy                           0.75        64
#    macro avg       0.75      0.75      0.75        64
# weighted avg       0.75      0.75      0.75        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74        32
#            1       0.74      0.72      0.73        32
#
#     accuracy                           0.73        64
#    macro avg       0.73      0.73      0.73        64
# weighted avg       0.73      0.73      0.73        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        32
#            1       0.85      0.72      0.78        32
#
#     accuracy                           0.80        64
#    macro avg       0.80      0.80      0.80        64
# weighted avg       0.80      0.80      0.80        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.72      0.81      0.76        32
#            1       0.79      0.69      0.73        32
#
#     accuracy                           0.75        64
#    macro avg       0.75      0.75      0.75        64
# weighted avg       0.75      0.75      0.75        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.73      0.84      0.78        32
#            1       0.81      0.69      0.75        32
#
#     accuracy                           0.77        64
#    macro avg       0.77      0.77      0.76        64
# weighted avg       0.77      0.77      0.76        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77        32
#            1       0.75      0.84      0.79        32
#
#     accuracy                           0.78        64
#    macro avg       0.79      0.78      0.78        64
# weighted avg       0.79      0.78      0.78        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.64      0.58      0.61        31
#            1       0.63      0.69      0.66        32
#
#     accuracy                           0.63        63
#    macro avg       0.64      0.63      0.63        63
# weighted avg       0.64      0.63      0.63        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74        31
#            1       0.75      0.75      0.75        32
#
#     accuracy                           0.75        63
#    macro avg       0.75      0.75      0.75        63
# weighted avg       0.75      0.75      0.75        63
#
# Cross Validation scores: [0.609375   0.71875    0.75       0.734375   0.796875   0.75
#  0.765625   0.78125    0.63492063 0.74603175]
#
#
# Cross Validation accuracy: 0.729 +/- 0.058

# %%
from sklearn.metrics import confusion_matrix as cm

m1 = cm(y_test,y_pred)
m1
# Out:
# array([[96, 42],
#        [38, 98]], dtype=int64)

# %%
df=pd.read_csv('ColumnFinal2.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

lr= LogisticRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))

x2=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x2.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores2 = cross_val_score(lr, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores2)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores2),np.std(scores2)))
# Out:
# accuracy 0.948905109489051
# Precision 0.9424460431654677
# Recall 0.9562043795620438
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        32
#            1       0.94      1.00      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        32
#            1       0.91      0.97      0.94        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        32
#            1       0.91      0.97      0.94        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        32
#            1       0.97      1.00      0.98        32
#
#     accuracy                           0.98        64
#    macro avg       0.98      0.98      0.98        64
# weighted avg       0.98      0.98      0.98        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        32
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93        31
#            1       0.91      0.97      0.94        32
#
#     accuracy                           0.94        63
#    macro avg       0.94      0.94      0.94        63
# weighted avg       0.94      0.94      0.94        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        32
#            1       1.00      0.97      0.98        31
#
#     accuracy                           0.98        63
#    macro avg       0.98      0.98      0.98        63
# weighted avg       0.98      0.98      0.98        63
#
# Cross Validation scores: [0.96875    0.96875    0.96875    0.9375     0.9375     0.984375
#  0.96875    1.         0.93650794 0.98412698]
#
#
# Cross Validation accuracy: 0.966 +/- 0.021

# %%
df=pd.read_csv('CValSet.csv')
A=df.drop('Label',axis=1)



# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=1, random_state=42) # 70% training and 30% test

X_train=scaler.transform(X_train)

scores4 = cross_val_score(lr, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores4)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores4),np.std(scores4)))
# Out:
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.87        46
#            1       0.97      1.00      0.98       304
#
#     accuracy                           0.97       350
#    macro avg       0.97      0.89      0.92       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88        46
#            1       0.98      0.98      0.98       304
#
#     accuracy                           0.97       350
#    macro avg       0.93      0.93      0.93       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.95      0.83      0.88        46
#            1       0.97      0.99      0.98       304
#
#     accuracy                           0.97       350
#    macro avg       0.96      0.91      0.93       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89        46
#            1       0.97      1.00      0.99       304
#
#     accuracy                           0.97       350
#    macro avg       0.97      0.91      0.94       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        46
#            1       0.98      0.99      0.99       304
#
#     accuracy                           0.98       350
#    macro avg       0.97      0.94      0.95       350
# weighted avg       0.98      0.98      0.98       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.95      0.83      0.88        46
#            1       0.97      0.99      0.98       303
#
#     accuracy                           0.97       349
#    macro avg       0.96      0.91      0.93       349
# weighted avg       0.97      0.97      0.97       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        45
#            1       0.98      0.99      0.98       304
#
#     accuracy                           0.97       349
#    macro avg       0.94      0.92      0.93       349
# weighted avg       0.97      0.97      0.97       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        45
#            1       0.97      0.98      0.98       304
#
#     accuracy                           0.96       349
#    macro avg       0.92      0.90      0.91       349
# weighted avg       0.96      0.96      0.96       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87        45
#            1       0.97      0.99      0.98       304
#
#     accuracy                           0.97       349
#    macro avg       0.95      0.91      0.93       349
# weighted avg       0.97      0.97      0.97       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88        45
#            1       0.98      0.98      0.98       304
#
#     accuracy                           0.97       349
#    macro avg       0.93      0.93      0.93       349
# weighted avg       0.97      0.97      0.97       349
#
# Cross Validation scores: [0.96857143 0.96857143 0.97142857 0.97428571 0.98       0.9713467
#  0.96848138 0.95988539 0.96848138 0.96848138]
#
#
# Cross Validation accuracy: 0.970 +/- 0.005

# %%
from sklearn.metrics import confusion_matrix as cm

m2 = cm(y_test,y_pred)
m2
# Out:
# array([[129,   8],
#        [  6, 131]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m1, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal1'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

unique, counts = np.unique(y_pred, return_counts=True)
print(unique)
print(counts)

ax= plt.subplot()
sns.heatmap(m2, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal2'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);
# Out:
# [0 1]
# [135 139]

# %%
def round_dict(d,k):
    res = dict()
    for key in d:
        res[key]=round(d[key],k)
    return res
        


def parse(d):
    fin = dict()
    i=-1
    k=3
    for key in d:
        i=i+1
        fin[i]=round_dict(key,k)
    fin = pd.DataFrame(fin,index= None)
    return(fin)
    
print(x1['0'])
print((parse(x1['0'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 19
#      16     fin = pd.DataFrame(fin,index= None)
#      17     return(fin)
# ---> 19 print(x1['0'])
#      20 print((parse(x1['0'])))
#
# TypeError: list indices must be integers or slices, not str

# %%
x1 = pd.DataFrame(x1,index=None)
x2 = pd.DataFrame(x2, index=None)

f1 = ["Label:0",parse(x1['0']),parse(x2['0'])]
f2 = ["Label:1",parse(x1['1']),parse(x2['1'])]
f3 = ["Accuracy",(x1['accuracy']),(x2['accuracy'])]
f4 = ["Macro Avg",parse(x1['macro avg']),parse(x2['macro avg'])]
f5 = ["Weighted Avg",parse(x1['weighted avg']),parse(x2['weighted avg'])]
f6 = ["Avg Accuracy",'%.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)),
      '%.3f +/- %.3f' % (np.mean(scores2),np.std(scores2))]
f = (f1,f2,f3,f4,f5,f6)

f = pd.DataFrame(f, columns = ['Types','Columns','Column+DecompWaves'], index = None)

print(f.shape)
f.to_csv('LRColumns.csv',index=None)
# Out:
# (6, 3)
