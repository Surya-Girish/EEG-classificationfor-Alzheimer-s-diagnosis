# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, make_scorer
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics

# %%
df=pd.read_csv('ColumnFinal1.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

nb = MultinomialNB()
nb.fit(X_train,y_train)

y_pred = nb.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))
# cv=10 represents the StratifiedKFold with 10 folds
x1=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x1.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores1 = cross_val_score(nb, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores1)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)))
# Out:
# accuracy 0.6897810218978102
# Precision 0.7297297297297297
# Recall 0.5955882352941176
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.53      0.66      0.58        32
#            1       0.54      0.41      0.46        32
#
#     accuracy                           0.53        64
#    macro avg       0.53      0.53      0.52        64
# weighted avg       0.53      0.53      0.52        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.61      0.69      0.65        32
#            1       0.64      0.56      0.60        32
#
#     accuracy                           0.62        64
#    macro avg       0.63      0.62      0.62        64
# weighted avg       0.63      0.62      0.62        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.59      0.81      0.68        32
#            1       0.70      0.44      0.54        32
#
#     accuracy                           0.62        64
#    macro avg       0.65      0.62      0.61        64
# weighted avg       0.65      0.62      0.61        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        32
#            1       0.59      0.62      0.61        32
#
#     accuracy                           0.59        64
#    macro avg       0.59      0.59      0.59        64
# weighted avg       0.59      0.59      0.59        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.66      0.78      0.71        32
#            1       0.73      0.59      0.66        32
#
#     accuracy                           0.69        64
#    macro avg       0.69      0.69      0.68        64
# weighted avg       0.69      0.69      0.68        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.56      0.69      0.62        32
#            1       0.60      0.47      0.53        32
#
#     accuracy                           0.58        64
#    macro avg       0.58      0.58      0.57        64
# weighted avg       0.58      0.58      0.57        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.56      0.69      0.62        32
#            1       0.60      0.47      0.53        32
#
#     accuracy                           0.58        64
#    macro avg       0.58      0.58      0.57        64
# weighted avg       0.58      0.58      0.57        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.68      0.81      0.74        32
#            1       0.77      0.62      0.69        32
#
#     accuracy                           0.72        64
#    macro avg       0.73      0.72      0.72        64
# weighted avg       0.73      0.72      0.72        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.54      0.68      0.60        31
#            1       0.58      0.44      0.50        32
#
#     accuracy                           0.56        63
#    macro avg       0.56      0.56      0.55        63
# weighted avg       0.56      0.56      0.55        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.54      0.68      0.60        31
#            1       0.58      0.44      0.50        32
#
#     accuracy                           0.56        63
#    macro avg       0.56      0.56      0.55        63
# weighted avg       0.56      0.56      0.55        63
#
# Cross Validation scores: [0.53125    0.625      0.625      0.59375    0.6875     0.578125
#  0.578125   0.71875    0.55555556 0.55555556]
#
#
# Cross Validation accuracy: 0.605 +/- 0.057

# %%
from sklearn.metrics import confusion_matrix as cm

m1 = cm(y_test,y_pred)
m1
# Out:
# array([[108,  30],
#        [ 55,  81]], dtype=int64)

# %%
df=pd.read_csv('ColumnFinal2.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = MinMaxScaler(feature_range=(0,1))
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

nb = MultinomialNB()
nb.fit(X_train,y_train)

y_pred = nb.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))
# cv=10 represents the StratifiedKFold with 10 folds
x2=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x2.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores2 = cross_val_score(nb, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores2)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores2),np.std(scores2)))
# Out:
# accuracy 0.7773722627737226
# Precision 0.7435897435897436
# Recall 0.8467153284671532
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86        32
#            1       0.80      1.00      0.89        32
#
#     accuracy                           0.88        64
#    macro avg       0.90      0.88      0.87        64
# weighted avg       0.90      0.88      0.87        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.85      0.72      0.78        32
#            1       0.76      0.88      0.81        32
#
#     accuracy                           0.80        64
#    macro avg       0.80      0.80      0.80        64
# weighted avg       0.80      0.80      0.80        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.86      0.56      0.68        32
#            1       0.67      0.91      0.77        32
#
#     accuracy                           0.73        64
#    macro avg       0.77      0.73      0.73        64
# weighted avg       0.77      0.73      0.73        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79        32
#            1       0.79      0.81      0.80        32
#
#     accuracy                           0.80        64
#    macro avg       0.80      0.80      0.80        64
# weighted avg       0.80      0.80      0.80        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.73      0.59      0.66        32
#            1       0.66      0.78      0.71        32
#
#     accuracy                           0.69        64
#    macro avg       0.69      0.69      0.68        64
# weighted avg       0.69      0.69      0.68        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81        32
#            1       0.77      0.94      0.85        32
#
#     accuracy                           0.83        64
#    macro avg       0.84      0.83      0.83        64
# weighted avg       0.84      0.83      0.83        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79        32
#            1       0.77      0.84      0.81        32
#
#     accuracy                           0.80        64
#    macro avg       0.80      0.80      0.80        64
# weighted avg       0.80      0.80      0.80        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        32
#            1       0.88      0.88      0.88        32
#
#     accuracy                           0.88        64
#    macro avg       0.88      0.88      0.88        64
# weighted avg       0.88      0.88      0.88        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.83      0.61      0.70        31
#            1       0.70      0.88      0.78        32
#
#     accuracy                           0.75        63
#    macro avg       0.76      0.74      0.74        63
# weighted avg       0.76      0.75      0.74        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.84      0.81      0.83        32
#            1       0.81      0.84      0.83        31
#
#     accuracy                           0.83        63
#    macro avg       0.83      0.83      0.83        63
# weighted avg       0.83      0.83      0.83        63
#
# Cross Validation scores: [0.875      0.796875   0.734375   0.796875   0.6875     0.828125
#  0.796875   0.875      0.74603175 0.82539683]
#
#
# Cross Validation accuracy: 0.796 +/- 0.057

# %%
df=pd.read_csv('CValSet.csv')
A=df.drop('Label',axis=1)

scaler = MinMaxScaler(feature_range=(0,1))

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=1, random_state=32) # 70% training and 30% test

X_train=scaler.fit_transform(X_train)
a=X_train

scores4 = cross_val_score(nb, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores4)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores4),np.std(scores4)))
# Out:
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        46
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       350
#    macro avg       0.43      0.50      0.46       350
# weighted avg       0.75      0.87      0.81       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        46
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       350
#    macro avg       0.43      0.50      0.46       350
# weighted avg       0.75      0.87      0.81       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        46
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       350
#    macro avg       0.43      0.50      0.46       350
# weighted avg       0.75      0.87      0.81       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        46
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       350
#    macro avg       0.43      0.50      0.46       350
# weighted avg       0.75      0.87      0.81       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        46
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       350
#    macro avg       0.43      0.50      0.46       350
# weighted avg       0.75      0.87      0.81       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        46
#            1       0.87      1.00      0.93       303
#
#     accuracy                           0.87       349
#    macro avg       0.43      0.50      0.46       349
# weighted avg       0.75      0.87      0.81       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        45
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       349
#    macro avg       0.44      0.50      0.47       349
# weighted avg       0.76      0.87      0.81       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        45
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       349
#    macro avg       0.44      0.50      0.46       349
# weighted avg       0.76      0.87      0.81       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        45
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       349
#    macro avg       0.44      0.50      0.47       349
# weighted avg       0.76      0.87      0.81       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        45
#            1       0.87      1.00      0.93       304
#
#     accuracy                           0.87       349
#    macro avg       0.44      0.50      0.47       349
# weighted avg       0.76      0.87      0.81       349
#
# Cross Validation scores: [0.86857143 0.86857143 0.86857143 0.86857143 0.86857143 0.86819484
#  0.87106017 0.86819484 0.87106017 0.87106017]
#
#
# Cross Validation accuracy: 0.869 +/- 0.001
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix as cm

m2 = cm(y_test,y_pred)
m2
# Out:
# array([[ 97,  40],
#        [ 21, 116]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m1, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal1'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

unique, counts = np.unique(y_pred, return_counts=True)
print(unique)
print(counts)

ax= plt.subplot()
sns.heatmap(m2, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal2'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);
# Out:
# [0 1]
# [118 156]

# %%
def round_dict(d,k):
    res = dict()
    for key in d:
        res[key]=round(d[key],k)
    return res
        


def parse(d):
    fin = dict()
    i=-1
    k=3
    for key in d:
        i=i+1
        fin[i]=round_dict(key,k)
    fin = pd.DataFrame(fin,index= None)
    return(fin)
    
print(x1['0'])
print((parse(x1['0'])))
# Out:
# 0    {'precision': 0.525, 'recall': 0.65625, 'f1-sc...
# 1    {'precision': 0.6111111111111112, 'recall': 0....
# 2    {'precision': 0.5909090909090909, 'recall': 0....
# 3    {'precision': 0.6, 'recall': 0.5625, 'f1-score...
# 4    {'precision': 0.6578947368421053, 'recall': 0....
# 5    {'precision': 0.5641025641025641, 'recall': 0....
# 6    {'precision': 0.5641025641025641, 'recall': 0....
# 7    {'precision': 0.6842105263157895, 'recall': 0....
# 8    {'precision': 0.5384615384615384, 'recall': 0....
# 9    {'precision': 0.5384615384615384, 'recall': 0....
# Name: 0, dtype: object
#                 0       1       2       3       4       5       6       7  \
# precision   0.525   0.611   0.591   0.600   0.658   0.564   0.564   0.684
# recall      0.656   0.688   0.812   0.562   0.781   0.688   0.688   0.812
# f1-score    0.583   0.647   0.684   0.581   0.714   0.620   0.620   0.743
# support    32.000  32.000  32.000  32.000  32.000  32.000  32.000  32.000
#
#                 8       9
# precision   0.538   0.538
# recall      0.677   0.677
# f1-score    0.600   0.600
# support    31.000  31.000

# %%
x1 = pd.DataFrame(x1,index=None)
x2 = pd.DataFrame(x2, index=None)

f1 = ["Label:0",parse(x1['0']),parse(x2['0'])]
f2 = ["Label:1",parse(x1['1']),parse(x2['1'])]
f3 = ["Accuracy",(x1['accuracy']),(x2['accuracy'])]
f4 = ["Macro Avg",parse(x1['macro avg']),parse(x2['macro avg'])]
f5 = ["Weighted Avg",parse(x1['weighted avg']),parse(x2['weighted avg'])]
f6 = ["Avg Accuracy",'%.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)),
      '%.3f +/- %.3f' % (np.mean(scores2),np.std(scores2))]
f = (f1,f2,f3,f4,f5,f6)

f = pd.DataFrame(f, columns = ['Types','Columns','Column+DecompWaves'], index = None)

print(f.shape)
f.to_csv('MNBColumns.csv',index=None)
# Out:
# (6, 3)
