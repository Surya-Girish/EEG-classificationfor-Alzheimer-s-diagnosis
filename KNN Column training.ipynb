# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing, metrics
from sklearn.preprocessing import  StandardScaler
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score, make_scorer
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ColumnFinal1.csv')
A=df.drop('Label',axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))

# cv=10 represents the StratifiedKFold with 10 folds
x1=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x1.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores1 = cross_val_score(knn, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores1)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)))
# Out:
# Accuracy: 0.7700729927007299
# Precision: 0.7552447552447552
# Recall: 0.7941176470588235
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.65      0.62      0.63        32
#            1       0.64      0.66      0.65        32
#
#     accuracy                           0.64        64
#    macro avg       0.64      0.64      0.64        64
# weighted avg       0.64      0.64      0.64        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68        32
#            1       0.68      0.72      0.70        32
#
#     accuracy                           0.69        64
#    macro avg       0.69      0.69      0.69        64
# weighted avg       0.69      0.69      0.69        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75        32
#            1       0.73      0.84      0.78        32
#
#     accuracy                           0.77        64
#    macro avg       0.77      0.77      0.76        64
# weighted avg       0.77      0.77      0.76        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74        32
#            1       0.74      0.72      0.73        32
#
#     accuracy                           0.73        64
#    macro avg       0.73      0.73      0.73        64
# weighted avg       0.73      0.73      0.73        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70        32
#            1       0.70      0.66      0.68        32
#
#     accuracy                           0.69        64
#    macro avg       0.69      0.69      0.69        64
# weighted avg       0.69      0.69      0.69        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        32
#            1       0.85      0.91      0.88        32
#
#     accuracy                           0.88        64
#    macro avg       0.88      0.88      0.87        64
# weighted avg       0.88      0.88      0.87        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71        32
#            1       0.71      0.75      0.73        32
#
#     accuracy                           0.72        64
#    macro avg       0.72      0.72      0.72        64
# weighted avg       0.72      0.72      0.72        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77        32
#            1       0.75      0.84      0.79        32
#
#     accuracy                           0.78        64
#    macro avg       0.79      0.78      0.78        64
# weighted avg       0.79      0.78      0.78        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.64      0.74      0.69        31
#            1       0.70      0.59      0.64        32
#
#     accuracy                           0.67        63
#    macro avg       0.67      0.67      0.67        63
# weighted avg       0.67      0.67      0.66        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81        31
#            1       0.83      0.78      0.81        32
#
#     accuracy                           0.81        63
#    macro avg       0.81      0.81      0.81        63
# weighted avg       0.81      0.81      0.81        63
#
# Cross Validation scores: [0.640625   0.6875     0.765625   0.734375   0.6875     0.875
#  0.71875    0.78125    0.66666667 0.80952381]
#
#
# Cross Validation accuracy: 0.737 +/- 0.068

# %%
from sklearn.metrics import confusion_matrix as cm

m1 = cm(y_test,y_pred)
m1
# Out:
# array([[103,  35],
#        [ 28, 108]], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing, metrics
from sklearn.preprocessing import  StandardScaler
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
import pandas as pd
import numpy as np

df=pd.read_csv('DecompWaveFeatures.csv')
A=df.drop('Label',axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))

# cv=10 represents the StratifiedKFold with 10 folds
x2=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x2.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores2 = cross_val_score(knn, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores2)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores2),np.std(scores2)))
# Out:
# Accuracy: 0.8029197080291971
# Precision: 0.8074074074074075
# Recall: 0.7956204379562044
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.88      0.66      0.75        32
#            1       0.72      0.91      0.81        32
#
#     accuracy                           0.78        64
#    macro avg       0.80      0.78      0.78        64
# weighted avg       0.80      0.78      0.78        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.77      0.84      0.81        32
#            1       0.83      0.75      0.79        32
#
#     accuracy                           0.80        64
#    macro avg       0.80      0.80      0.80        64
# weighted avg       0.80      0.80      0.80        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.75      0.84      0.79        32
#            1       0.82      0.72      0.77        32
#
#     accuracy                           0.78        64
#    macro avg       0.79      0.78      0.78        64
# weighted avg       0.79      0.78      0.78        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77        32
#            1       0.77      0.75      0.76        32
#
#     accuracy                           0.77        64
#    macro avg       0.77      0.77      0.77        64
# weighted avg       0.77      0.77      0.77        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        32
#            1       0.85      0.72      0.78        32
#
#     accuracy                           0.80        64
#    macro avg       0.80      0.80      0.80        64
# weighted avg       0.80      0.80      0.80        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88        32
#            1       0.93      0.81      0.87        32
#
#     accuracy                           0.88        64
#    macro avg       0.88      0.88      0.87        64
# weighted avg       0.88      0.88      0.87        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83        32
#            1       0.81      0.91      0.85        32
#
#     accuracy                           0.84        64
#    macro avg       0.85      0.84      0.84        64
# weighted avg       0.85      0.84      0.84        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92        32
#            1       0.94      0.91      0.92        32
#
#     accuracy                           0.92        64
#    macro avg       0.92      0.92      0.92        64
# weighted avg       0.92      0.92      0.92        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        31
#            1       0.86      0.75      0.80        32
#
#     accuracy                           0.81        63
#    macro avg       0.81      0.81      0.81        63
# weighted avg       0.81      0.81      0.81        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.89        32
#            1       0.85      0.94      0.89        31
#
#     accuracy                           0.89        63
#    macro avg       0.89      0.89      0.89        63
# weighted avg       0.89      0.89      0.89        63
#
# Cross Validation scores: [0.78125    0.796875   0.78125    0.765625   0.796875   0.875
#  0.84375    0.921875   0.80952381 0.88888889]
#
#
# Cross Validation accuracy: 0.826 +/- 0.050

# %%
from sklearn.metrics import confusion_matrix as cm

m2 = cm(y_test,y_pred)
m2
# Out:
# array([[111,  26],
#        [ 28, 109]], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing, metrics
from sklearn.preprocessing import  StandardScaler
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
import pandas as pd
import numpy as np

df=pd.read_csv('ColumnFinal2.csv')
A=df.drop('Label',axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))

# cv=10 represents the StratifiedKFold with 10 folds
x3=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x3.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores3 = cross_val_score(knn, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores3)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores3),np.std(scores3)))
# Out:
# Accuracy: 0.9124087591240876
# Precision: 0.8843537414965986
# Recall: 0.948905109489051
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        32
#            1       0.94      0.94      0.94        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85        32
#            1       0.83      0.91      0.87        32
#
#     accuracy                           0.86        64
#    macro avg       0.86      0.86      0.86        64
# weighted avg       0.86      0.86      0.86        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92        32
#            1       0.89      0.97      0.93        32
#
#     accuracy                           0.92        64
#    macro avg       0.93      0.92      0.92        64
# weighted avg       0.93      0.92      0.92        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92        32
#            1       0.89      0.97      0.93        32
#
#     accuracy                           0.92        64
#    macro avg       0.93      0.92      0.92        64
# weighted avg       0.93      0.92      0.92        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94        32
#            1       0.97      0.91      0.94        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        32
#            1       0.94      0.94      0.94        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93        31
#            1       0.91      0.97      0.94        32
#
#     accuracy                           0.94        63
#    macro avg       0.94      0.94      0.94        63
# weighted avg       0.94      0.94      0.94        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        32
#            1       0.91      0.97      0.94        31
#
#     accuracy                           0.94        63
#    macro avg       0.94      0.94      0.94        63
# weighted avg       0.94      0.94      0.94        63
#
# Cross Validation scores: [0.96875    0.9375     0.859375   0.921875   0.921875   0.96875
#  0.9375     0.9375     0.93650794 0.93650794]
#
#
# Cross Validation accuracy: 0.933 +/- 0.029

# %%
df=pd.read_csv('CValSet.csv')
A=df.drop('Label',axis=1)



# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=1, random_state=42) # 70% training and 30% test

X_train=scaler.transform(X_train)

scores4 = cross_val_score(knn, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores4)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores4),np.std(scores4)))
# Out:
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.70      0.81        46
#            1       0.96      1.00      0.98       304
#
#     accuracy                           0.96       350
#    macro avg       0.96      0.85      0.89       350
# weighted avg       0.96      0.96      0.95       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88        46
#            1       0.97      1.00      0.98       304
#
#     accuracy                           0.97       350
#    macro avg       0.97      0.90      0.93       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80        46
#            1       0.96      0.99      0.97       304
#
#     accuracy                           0.95       350
#    macro avg       0.95      0.84      0.89       350
# weighted avg       0.95      0.95      0.95       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89        46
#            1       0.97      1.00      0.99       304
#
#     accuracy                           0.97       350
#    macro avg       0.97      0.91      0.94       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89        46
#            1       0.97      1.00      0.99       304
#
#     accuracy                           0.97       350
#    macro avg       0.97      0.91      0.94       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88        46
#            1       0.97      1.00      0.98       303
#
#     accuracy                           0.97       349
#    macro avg       0.97      0.90      0.93       349
# weighted avg       0.97      0.97      0.97       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.71      0.82        45
#            1       0.96      1.00      0.98       304
#
#     accuracy                           0.96       349
#    macro avg       0.96      0.85      0.90       349
# weighted avg       0.96      0.96      0.96       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88        45
#            1       0.97      1.00      0.98       304
#
#     accuracy                           0.97       349
#    macro avg       0.97      0.90      0.93       349
# weighted avg       0.97      0.97      0.97       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78        45
#            1       0.95      0.99      0.97       304
#
#     accuracy                           0.95       349
#    macro avg       0.95      0.83      0.88       349
# weighted avg       0.95      0.95      0.95       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.73      0.83        45
#            1       0.96      0.99      0.98       304
#
#     accuracy                           0.96       349
#    macro avg       0.95      0.86      0.90       349
# weighted avg       0.96      0.96      0.96       349
#
# Cross Validation scores: [0.95714286 0.97142857 0.95428571 0.97428571 0.97428571 0.9713467
#  0.95988539 0.9713467  0.9512894  0.95988539]
#
#
# Cross Validation accuracy: 0.965 +/- 0.008

# %%
from sklearn.metrics import confusion_matrix as cm

m3 = cm(y_test,y_pred)
m3
# Out:
# array([[120,  17],
#        [  7, 130]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m1, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal1'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m2, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for DecompWaveFeatures'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

unique, counts = np.unique(y_pred, return_counts=True)
print(unique)
print(counts)

ax= plt.subplot()
sns.heatmap(m3, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal2'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);
# Out:
# [0 1]
# [127 147]

# %%
def round_dict(d,k):
    res = dict()
    for key in d:
        res[key]=round(d[key],k)
    return res
        


def parse(d):
    fin = dict()
    i=-1
    k=3
    for key in d:
        i=i+1
        fin[i]=round_dict(key,k)
    fin = pd.DataFrame(fin,index= None)
    return(fin)
 

    
print(x1['0'])
print((parse(x1['0'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 21
#      16     fin = pd.DataFrame(fin,index= None)
#      17     return(fin)
# ---> 21 print(x1['0'])
#      22 print((parse(x1['0'])))
#
# TypeError: list indices must be integers or slices, not str

# %%
x1 = pd.DataFrame(x1,index=None)
x2 = pd.DataFrame(x2, index=None)
x3 = pd.DataFrame(x3, index=None)

f1 = ["Label:0",parse(x1['0']),parse(x2['0']),parse(x3['0'])]
f2 = ["Label:1",parse(x1['1']),parse(x2['1']),parse(x3['1'])]
f3 = ["Accuracy",(x1['accuracy']),(x2['accuracy']),(x3['accuracy'])]
f4 = ["Macro Avg",parse(x1['macro avg']),parse(x2['macro avg']),parse(x3['macro avg'])]
f5 = ["Weighted Avg",parse(x1['weighted avg']),parse(x2['weighted avg']),parse(x3['weighted avg'])]
f6 = ["Avg Accuracy",'%.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)),
      '%.3f +/- %.3f' % (np.mean(scores2),np.std(scores2))
      ,'%.3f +/- %.3f' % (np.mean(scores3),np.std(scores3))]
f = (f1,f2,f3,f4,f5,f6)

f = pd.DataFrame(f, columns = ['Types','Columns','DecomWaves','Column+DecompWaves'], index = None)

print(f.shape)
f.to_csv('KNNColumns.csv',index=None)
# Out:
# (6, 4)
