# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, make_scorer
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics

# %%
df=pd.read_csv('ColumnFinal1.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)

y_pred = nb.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))
# cv=10 represents the StratifiedKFold with 10 folds
x1=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x1.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores1 = cross_val_score(nb, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores1)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)))
# Out:
# accuracy 0.708029197080292
# Precision 0.7089552238805971
# Recall 0.6985294117647058
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.61      0.53      0.57        32
#            1       0.58      0.66      0.62        32
#
#     accuracy                           0.59        64
#    macro avg       0.60      0.59      0.59        64
# weighted avg       0.60      0.59      0.59        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        32
#            1       0.59      0.62      0.61        32
#
#     accuracy                           0.59        64
#    macro avg       0.59      0.59      0.59        64
# weighted avg       0.59      0.59      0.59        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59        32
#            1       0.60      0.66      0.63        32
#
#     accuracy                           0.61        64
#    macro avg       0.61      0.61      0.61        64
# weighted avg       0.61      0.61      0.61        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.58      0.44      0.50        32
#            1       0.55      0.69      0.61        32
#
#     accuracy                           0.56        64
#    macro avg       0.57      0.56      0.56        64
# weighted avg       0.57      0.56      0.56        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.71      0.62      0.67        32
#            1       0.67      0.75      0.71        32
#
#     accuracy                           0.69        64
#    macro avg       0.69      0.69      0.69        64
# weighted avg       0.69      0.69      0.69        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        32
#            1       0.62      0.62      0.62        32
#
#     accuracy                           0.62        64
#    macro avg       0.62      0.62      0.62        64
# weighted avg       0.62      0.62      0.62        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        32
#            1       0.59      0.62      0.61        32
#
#     accuracy                           0.59        64
#    macro avg       0.59      0.59      0.59        64
# weighted avg       0.59      0.59      0.59        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.67      0.56      0.61        32
#            1       0.62      0.72      0.67        32
#
#     accuracy                           0.64        64
#    macro avg       0.64      0.64      0.64        64
# weighted avg       0.64      0.64      0.64        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.53      0.52      0.52        31
#            1       0.55      0.56      0.55        32
#
#     accuracy                           0.54        63
#    macro avg       0.54      0.54      0.54        63
# weighted avg       0.54      0.54      0.54        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.68      0.74      0.71        31
#            1       0.72      0.66      0.69        32
#
#     accuracy                           0.70        63
#    macro avg       0.70      0.70      0.70        63
# weighted avg       0.70      0.70      0.70        63
#
# Cross Validation scores: [0.59375    0.59375    0.609375   0.5625     0.6875     0.625
#  0.59375    0.640625   0.53968254 0.6984127 ]
#
#
# Cross Validation accuracy: 0.614 +/- 0.048

# %%
from sklearn.metrics import confusion_matrix as cm

m1 = cm(y_test,y_pred)
m1
# Out:
# array([[99, 39],
#        [41, 95]], dtype=int64)

# %%
df=pd.read_csv('ColumnFinal2.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

nb = GaussianNB()
nb.fit(X_train,y_train)

y_pred = nb.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))
# cv=10 represents the StratifiedKFold with 10 folds
x2=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x2.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores2 = cross_val_score(nb, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores2)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores2),np.std(scores2)))
# Out:
# accuracy 0.8832116788321168
# Precision 0.847682119205298
# Recall 0.9343065693430657
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        32
#            1       0.91      1.00      0.96        32
#
#     accuracy                           0.95        64
#    macro avg       0.96      0.95      0.95        64
# weighted avg       0.96      0.95      0.95        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        32
#            1       0.90      0.88      0.89        32
#
#     accuracy                           0.89        64
#    macro avg       0.89      0.89      0.89        64
# weighted avg       0.89      0.89      0.89        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85        32
#            1       0.81      0.94      0.87        32
#
#     accuracy                           0.86        64
#    macro avg       0.87      0.86      0.86        64
# weighted avg       0.87      0.86      0.86        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        32
#            1       1.00      0.88      0.93        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        32
#            1       0.85      0.91      0.88        32
#
#     accuracy                           0.88        64
#    macro avg       0.88      0.88      0.87        64
# weighted avg       0.88      0.88      0.87        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90        32
#            1       0.88      0.94      0.91        32
#
#     accuracy                           0.91        64
#    macro avg       0.91      0.91      0.91        64
# weighted avg       0.91      0.91      0.91        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92        32
#            1       0.91      0.94      0.92        32
#
#     accuracy                           0.92        64
#    macro avg       0.92      0.92      0.92        64
# weighted avg       0.92      0.92      0.92        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91        32
#            1       0.96      0.84      0.90        32
#
#     accuracy                           0.91        64
#    macro avg       0.91      0.91      0.91        64
# weighted avg       0.91      0.91      0.91        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.96      0.77      0.86        31
#            1       0.82      0.97      0.89        32
#
#     accuracy                           0.87        63
#    macro avg       0.89      0.87      0.87        63
# weighted avg       0.89      0.87      0.87        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        32
#            1       0.93      0.87      0.90        31
#
#     accuracy                           0.90        63
#    macro avg       0.91      0.90      0.90        63
# weighted avg       0.91      0.90      0.90        63
#
# Cross Validation scores: [0.953125   0.890625   0.859375   0.9375     0.875      0.90625
#  0.921875   0.90625    0.87301587 0.9047619 ]
#
#
# Cross Validation accuracy: 0.903 +/- 0.028

# %%
df=pd.read_csv('CValSet.csv')
A=df.drop('Label',axis=1)



# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=1, random_state=42) # 70% training and 30% test

X_train=scaler.transform(X_train)

scores4 = cross_val_score(nb, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores4)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores4),np.std(scores4)))
# Out:
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.15      1.00      0.26        46
#            1       1.00      0.12      0.22       304
#
#     accuracy                           0.24       350
#    macro avg       0.57      0.56      0.24       350
# weighted avg       0.89      0.24      0.23       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.15      1.00      0.25        46
#            1       1.00      0.11      0.20       304
#
#     accuracy                           0.23       350
#    macro avg       0.57      0.55      0.22       350
# weighted avg       0.89      0.23      0.20       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25        46
#            1       1.00      0.10      0.17       304
#
#     accuracy                           0.21       350
#    macro avg       0.57      0.55      0.21       350
# weighted avg       0.89      0.21      0.18       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.24        46
#            1       1.00      0.05      0.10       304
#
#     accuracy                           0.18       350
#    macro avg       0.57      0.53      0.17       350
# weighted avg       0.89      0.18      0.12       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25        46
#            1       1.00      0.11      0.19       304
#
#     accuracy                           0.22       350
#    macro avg       0.57      0.55      0.22       350
# weighted avg       0.89      0.22      0.20       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25        46
#            1       1.00      0.09      0.16       303
#
#     accuracy                           0.21       349
#    macro avg       0.57      0.54      0.21       349
# weighted avg       0.89      0.21      0.18       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25        45
#            1       1.00      0.10      0.17       304
#
#     accuracy                           0.21       349
#    macro avg       0.57      0.55      0.21       349
# weighted avg       0.89      0.21      0.18       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25        45
#            1       1.00      0.11      0.20       304
#
#     accuracy                           0.23       349
#    macro avg       0.57      0.56      0.23       349
# weighted avg       0.89      0.23      0.21       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25        45
#            1       1.00      0.11      0.19       304
#
#     accuracy                           0.22       349
#    macro avg       0.57      0.55      0.22       349
# weighted avg       0.89      0.22      0.20       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.14      1.00      0.24        45
#            1       1.00      0.07      0.13       304
#
#     accuracy                           0.19       349
#    macro avg       0.57      0.54      0.19       349
# weighted avg       0.89      0.19      0.15       349
#
# Cross Validation scores: [0.24       0.22571429 0.21428571 0.17714286 0.22285714 0.20916905
#  0.21203438 0.22636103 0.22063037 0.19197708]
#
#
# Cross Validation accuracy: 0.214 +/- 0.017

# %%
from sklearn.metrics import confusion_matrix as cm

m2 = cm(y_test,y_pred)
m2
# Out:
# array([[114,  23],
#        [  9, 128]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m1, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal1'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

unique, counts = np.unique(y_pred, return_counts=True)
print(unique)
print(counts)

ax= plt.subplot()
sns.heatmap(m2, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal2'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);
# Out:
# [0 1]
# [123 151]

# %%
def round_dict(d,k):
    res = dict()
    for key in d:
        res[key]=round(d[key],k)
    return res
        


def parse(d):
    fin = dict()
    i=-1
    k=3
    for key in d:
        i=i+1
        fin[i]=round_dict(key,k)
    fin = pd.DataFrame(fin,index= None)
    return(fin)
    
print(x1['0'])
print((parse(x1['0'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 19
#      16     fin = pd.DataFrame(fin,index= None)
#      17     return(fin)
# ---> 19 print(x1['0'])
#      20 print((parse(x1['0'])))
#
# TypeError: list indices must be integers or slices, not str

# %%
x1 = pd.DataFrame(x1,index=None)
x2 = pd.DataFrame(x2, index=None)

f1 = ["Label:0",parse(x1['0']),parse(x2['0'])]
f2 = ["Label:1",parse(x1['1']),parse(x2['1'])]
f3 = ["Accuracy",(x1['accuracy']),(x2['accuracy'])]
f4 = ["Macro Avg",parse(x1['macro avg']),parse(x2['macro avg'])]
f5 = ["Weighted Avg",parse(x1['weighted avg']),parse(x2['weighted avg'])]
f6 = ["Avg Accuracy",'%.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)),
      '%.3f +/- %.3f' % (np.mean(scores2),np.std(scores2))]
f = (f1,f2,f3,f4,f5,f6)

f = pd.DataFrame(f, columns = ['Types','Columns','Column+DecompWaves'], index = None)

print(f.shape)
f.to_csv('GNBColumns.csv',index=None)
# Out:
# (6, 3)
