# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, make_scorer, classification_report
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics

# %%
df=pd.read_csv('ColumnFinal1.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Instantiate model with 1000 decision trees
rf = RandomForestClassifier(n_estimators=1000)
# Train the model on training data
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))
# cv=10 represents the StratifiedKFold with 10 folds
x1=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred, digits = 2))
    x1.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores1 = cross_val_score(rf, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores1)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)))
# Out:
# accuracy 0.9562043795620438
# Precision 0.9629629629629629
# Recall 0.948905109489051
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        32
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        32
#            1       0.97      0.94      0.95        32
#
#     accuracy                           0.95        64
#    macro avg       0.95      0.95      0.95        64
# weighted avg       0.95      0.95      0.95        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        32
#            1       0.94      0.94      0.94        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        32
#            1       1.00      0.94      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        32
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        32
#            1       0.97      1.00      0.98        32
#
#     accuracy                           0.98        64
#    macro avg       0.98      0.98      0.98        64
# weighted avg       0.98      0.98      0.98        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        32
#            1       1.00      0.97      0.98        32
#
#     accuracy                           0.98        64
#    macro avg       0.98      0.98      0.98        64
# weighted avg       0.98      0.98      0.98        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        32
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93        31
#            1       0.91      0.97      0.94        32
#
#     accuracy                           0.94        63
#    macro avg       0.94      0.94      0.94        63
# weighted avg       0.94      0.94      0.94        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        32
#            1       0.97      1.00      0.98        31
#
#     accuracy                           0.98        63
#    macro avg       0.98      0.98      0.98        63
# weighted avg       0.98      0.98      0.98        63
#
# Cross Validation scores: [1.         0.953125   0.9375     0.96875    1.         0.984375
#  0.984375   1.         0.93650794 0.98412698]
#
#
# Cross Validation accuracy: 0.975 +/- 0.024

# %%
from sklearn.metrics import confusion_matrix as cm

m1 = cm(y_test,y_pred)
m1
# Out:
# array([[115,  23],
#        [ 23, 113]], dtype=int64)

# %%
df=pd.read_csv('ColumnFinal2.csv')
df2=pd.read_csv('Trial.csv')
x=df.drop('Label',axis=1)
y=df.Label
a=df2.drop('Label',axis=1)
b=df2.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)
a, c, b, d = train_test_split(x,y, test_size=0.1, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
a = scaler.transform(a)

# Instantiate model with 1000 decision trees
rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)

# Train the model on training data
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

print("accuracy", accuracy_score(y_test,y_pred))

print("Precision", metrics.precision_score(y_test,y_pred))

print("Recall", metrics.recall_score(y_test,y_pred))
# cv=10 represents the StratifiedKFold with 10 folds
x2=[]
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x2.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores2 = cross_val_score(rf, X=a, y=b, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores2)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores2),np.std(scores2)))
# Out:
# accuracy 0.9635036496350365
# Precision 0.9703703703703703
# Recall 0.9562043795620438
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        40
#            1       0.97      0.88      0.93        42
#
#     accuracy                           0.93        82
#    macro avg       0.93      0.93      0.93        82
# weighted avg       0.93      0.93      0.93        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        42
#
#     accuracy                           1.00        82
#    macro avg       1.00      1.00      1.00        82
# weighted avg       1.00      1.00      1.00        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        40
#            1       1.00      1.00      1.00        42
#
#     accuracy                           1.00        82
#    macro avg       1.00      1.00      1.00        82
# weighted avg       1.00      1.00      1.00        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        41
#            1       1.00      0.98      0.99        41
#
#     accuracy                           0.99        82
#    macro avg       0.99      0.99      0.99        82
# weighted avg       0.99      0.99      0.99        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        41
#            1       0.95      0.98      0.96        41
#
#     accuracy                           0.96        82
#    macro avg       0.96      0.96      0.96        82
# weighted avg       0.96      0.96      0.96        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        41
#
#     accuracy                           1.00        82
#    macro avg       1.00      1.00      1.00        82
# weighted avg       1.00      1.00      1.00        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.98      1.00      0.99        41
#
#     accuracy                           0.99        82
#    macro avg       0.99      0.99      0.99        82
# weighted avg       0.99      0.99      0.99        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        41
#            1       1.00      0.98      0.99        41
#
#     accuracy                           0.99        82
#    macro avg       0.99      0.99      0.99        82
# weighted avg       0.99      0.99      0.99        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        41
#            1       0.95      1.00      0.98        41
#
#     accuracy                           0.98        82
#    macro avg       0.98      0.98      0.98        82
# weighted avg       0.98      0.98      0.98        82
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        41
#
#     accuracy                           1.00        82
#    macro avg       1.00      1.00      1.00        82
# weighted avg       1.00      1.00      1.00        82
#
# Cross Validation scores: [0.92682927 1.         1.         0.98780488 0.96341463 1.
#  0.98780488 0.98780488 0.97560976 1.        ]
#
#
# Cross Validation accuracy: 0.983 +/- 0.022

# %%
df=pd.read_csv('CValSet.csv')
A=df.drop('Label',axis=1)



# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=1, random_state=42) # 70% training and 30% test

X_train=scaler.transform(X_train)

scores4 = cross_val_score(rf, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores4)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores4),np.std(scores4)))
# Out:
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89        46
#            1       0.97      1.00      0.99       304
#
#     accuracy                           0.97       350
#    macro avg       0.97      0.91      0.94       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        46
#            1       0.99      1.00      0.99       304
#
#     accuracy                           0.99       350
#    macro avg       0.99      0.96      0.97       350
# weighted avg       0.99      0.99      0.99       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        46
#            1       0.98      1.00      0.99       304
#
#     accuracy                           0.98       350
#    macro avg       0.99      0.93      0.96       350
# weighted avg       0.98      0.98      0.98       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90        46
#            1       0.97      1.00      0.99       304
#
#     accuracy                           0.98       350
#    macro avg       0.99      0.91      0.95       350
# weighted avg       0.98      0.98      0.98       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        46
#            1       0.99      1.00      1.00       304
#
#     accuracy                           0.99       350
#    macro avg       0.99      0.98      0.98       350
# weighted avg       0.99      0.99      0.99       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        46
#            1       0.98      1.00      0.99       303
#
#     accuracy                           0.99       349
#    macro avg       0.99      0.95      0.97       349
# weighted avg       0.99      0.99      0.99       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95        45
#            1       0.99      1.00      0.99       304
#
#     accuracy                           0.99       349
#    macro avg       0.98      0.97      0.97       349
# weighted avg       0.99      0.99      0.99       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        45
#            1       0.98      1.00      0.99       304
#
#     accuracy                           0.99       349
#    macro avg       0.99      0.94      0.97       349
# weighted avg       0.99      0.99      0.99       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        45
#            1       0.99      1.00      1.00       304
#
#     accuracy                           0.99       349
#    macro avg       1.00      0.98      0.99       349
# weighted avg       0.99      0.99      0.99       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        45
#            1       0.99      1.00      1.00       304
#
#     accuracy                           0.99       349
#    macro avg       0.99      0.98      0.98       349
# weighted avg       0.99      0.99      0.99       349
#
# Cross Validation scores: [0.97428571 0.98857143 0.98285714 0.97714286 0.99142857 0.98567335
#  0.98853868 0.98567335 0.99426934 0.99140401]
#
#
# Cross Validation accuracy: 0.986 +/- 0.006

# %%
from sklearn.metrics import confusion_matrix as cm

m2 = cm(y_test,y_pred)
m2
# Out:
# array([[133,   4],
#        [  6, 131]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m1, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal1'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

unique, counts = np.unique(y_pred, return_counts=True)
print(unique)
print(counts)

ax= plt.subplot()
sns.heatmap(m2, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal2'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);
# Out:
# [0 1]
# [139 135]

# %%
def round_dict(d,k):
    res = dict()
    for key in d:
        res[key]=round(d[key],k)
    return res
        


def parse(d):
    fin = dict()
    i=-1
    k=3
    for key in d:
        i=i+1
        fin[i]=round_dict(key,k)
    fin = pd.DataFrame(fin,index= None)
    return(fin)
    
print(x1['0'])
print((parse(x1['0'])))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 19
#      16     fin = pd.DataFrame(fin,index= None)
#      17     return(fin)
# ---> 19 print(x1['0'])
#      20 print((parse(x1['0'])))
#
# File ~\anaconda\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '0'

# %%
x1 = pd.DataFrame(x1,index=None)
x2 = pd.DataFrame(x2, index=None)

f1 = ["Label:0",parse(x1['0']),parse(x2['0'])]
f2 = ["Label:1",parse(x1['1']),parse(x2['1'])]
f3 = ["Accuracy",(x1['accuracy']),(x2['accuracy'])]
f4 = ["Macro Avg",parse(x1['macro avg']),parse(x2['macro avg'])]
f5 = ["Weighted Avg",parse(x1['weighted avg']),parse(x2['weighted avg'])]
f6 = ["Avg Accuracy",'%.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)),
      '%.3f +/- %.3f' % (np.mean(scores2),np.std(scores2))]
f = (f1,f2,f3,f4,f5,f6)

f = pd.DataFrame(f, columns = ['Types','Columns','Column+DecompWaves'], index = None)

print(f.shape)
f.to_csv('RFColumns.csv',index=None)
# Out:
# (6, 3)
