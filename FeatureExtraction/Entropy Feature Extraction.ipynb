# %%
""" BEFORE EXTRACTING FEATURES FROM WAVELET COEFFECIENTS CHECK THE SHAPE OF INPUT DATASET!!!"""

from numpy import genfromtxt
from pyentrp import entropy
import numpy as np
import math

def renyi_entropy(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12):

    d1=np.rint(d1)
    d2=np.rint(d2)
    d3=np.rint(d3)
    d4=np.rint(d4)
    d5=np.rint(d5)
    d6=np.rint(d6)
    d7=np.rint(d7)
    d8=np.rint(d8)
    d9=np.rint(d9)
    d10=np.rint(d10)
    d11=np.rint(d11)
    d12=np.rint(d12)
    
    rend1=[];rend2=[];rend3=[];rend4=[];rend5=[];rend6=[];rend7=[];rend8=[];rend9=[];rend10=[];rend11=[];
    rend12=[];
    alpha=2    
    for i in range(0,19):
        X=d1[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend1.append(Renyi_En)

    for i in range(0,19):
        X=d2[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend2.append(Renyi_En)

    for i in range(0,19):
        X=d3[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend3.append(Renyi_En)

    for i in range(0,19):
        X=d4[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend4.append(Renyi_En)

    for i in range(0,19):
        X=d5[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend5.append(Renyi_En)
    
    for i in range(0,19):
        X=d6[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend6.append(Renyi_En)
        
    for i in range(0,19):
        X=d7[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend7.append(Renyi_En)
        
    for i in range(0,19):
        X=d8[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend8.append(Renyi_En)
        
    for i in range(0,19):
        X=d9[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend9.append(Renyi_En)
        
    for i in range(0,19):
        X=d10[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend10.append(Renyi_En)
        
    for i in range(0,19):
        X=d11[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend11.append(Renyi_En)
        
    for i in range(0,19):
        X=d12[i]
        data_set = list(set(X))
        freq_list = []
        for entry in data_set:
            counter = 0.
            for i in X:
                if i == entry:
                    counter += 1
            freq_list.append(float(counter)/len(X))
        summation=0
        for freq in freq_list:
            summation+=math.pow(freq,alpha)
        Renyi_En=(1/float(1-alpha))*(math.log(summation,2))
        rend12.append(Renyi_En)
        
        
    return(rend1,rend2,rend3,rend4,rend5,rend6,rend7,rend8,rend9,rend10,rend11,rend12)

def permu(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12):
    
    pd1=[];pd2=[];pd3=[];pd4=[];pd5=[];pd6=[];pd7=[];pd8=[];pd9=[];pd10=[];pd11=[];pd12=[];
    
    for i in range(0,19):
        X=d1[i]
        pd1.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d2[i]
        pd2.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d3[i]
        pd3.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d4[i]
        pd4.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d5[i]
        pd5.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d6[i]
        pd6.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d7[i]
        pd7.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d8[i]
        pd8.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d9[i]
        pd9.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d10[i]
        pd10.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d11[i]
        pd11.append(entropy.permutation_entropy(X,3,1))
    for i in range(0,19):
        X=d12[i]
        pd12.append(entropy.permutation_entropy(X,3,1))


    return(pd1,pd2,pd3,pd4,pd5,pd6,pd7,pd8,pd9,pd10,pd11,pd12)
    
def sampl(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12):

    sa1=[];sa2=[];sa3=[];sa4=[];sa5=[];sa6=[];sa7=[];sa8=[];sa9=[];sa10=[];sa11=[];sa12=[];

    for i in range(0,19):
        X=d1[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa1.append(ee[0])

    for i in range(0,19):
        X=d2[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa2.append(ee[0])

    for i in range(0,19):
        X=d3[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa3.append(ee[0])

    for i in range(0,19):
        X=d4[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa4.append(ee[0])

    for i in range(0,19):
        X=d5[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa5.append(ee[0])
    
    for i in range(0,19):
        X=d6[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa6.append(ee[0])

    for i in range(0,19):
        X=d7[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa7.append(ee[0])

    for i in range(0,19):
        X=d8[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa8.append(ee[0])
    
    for i in range(0,19):
        X=d9[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa9.append(ee[0])

    for i in range(0,19):
        X=d10[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa10.append(ee[0])

    for i in range(0,19):
        X=d11[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa11.append(ee[0])
    
    for i in range(0,19):
        X=d12[i]
        std_X = np.std(X)
        ee=entropy.sample_entropy(X,2,0.2*std_X)
        sa12.append(ee[0])

    return(sa1,sa2,sa3,sa4,sa5,sa6,sa7,sa8,sa9,sa10,sa11,sa12)

def shan(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12):

    sh1=[];sh2=[];sh3=[];sh4=[];sh5=[];sh6=[];sh7=[];sh8=[];sh9=[];sh10=[];sh11=[];sh12=[];
    d1=np.rint(d1)
    d2=np.rint(d2)
    d3=np.rint(d3)
    d4=np.rint(d4)
    d5=np.rint(d5)
    d6=np.rint(d6)
    d7=np.rint(d7)
    d8=np.rint(d8)
    d9=np.rint(d9)
    d10=np.rint(d10)
    d11=np.rint(d11)
    d12=np.rint(d12)
    for i in range(0,19):
        X=d1[i]
        sh1.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d2[i]
        sh2.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d3[i]
        sh3.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d4[i]
        sh4.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d5[i]
        sh5.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d6[i]
        sh6.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d7[i]
        sh7.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d8[i]
        sh8.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d9[i]
        sh9.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d10[i]
        sh10.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d11[i]
        sh11.append(entropy.shannon_entropy(X))
    for i in range(0,19):
        X=d12[i]
        sh12.append(entropy.shannon_entropy(X))
    return(sh1,sh2,sh3,sh4,sh5,sh6,sh7,sh8,sh9,sh10,sh11,sh12)


def energy(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12):

    en1=[];en2=[];en3=[];en4=[];en5=[];en6=[];en7=[];en8=[];en9=[];en10=[];en11=[];en12=[];
    for i in range(0,19):
        X=d1[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en1.append(summ)
    for i in range(0,19):
        X=d2[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en2.append(summ)
    for i in range(0,19):
        X=d3[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en3.append(summ)
    for i in range(0,19):
        X=d4[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en4.append(summ)
    for i in range(0,19):
        X=d5[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en5.append(summ)
    for i in range(0,19):
        X=d6[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en6.append(summ)
    for i in range(0,19):
        X=d7[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en7.append(summ)
    for i in range(0,19):
        X=d8[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en8.append(summ)  
    for i in range(0,19):
        X=d9[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en9.append(summ)
    for i in range(0,19):
        X=d10[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en10.append(summ)
    for i in range(0,19):
        X=d11[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en11.append(summ)
    for i in range(0,19):
        X=d12[i]
        summ=0
        for i in X:
            summ+=(i**2)
        en12.append(summ)
    

    return(en1,en2,en3,en4,en5,en6,en7,en8,en9,en10,en11,en12)

d1= genfromtxt('eeg20o1.csv', delimiter=',', skip_header=0)
d2= genfromtxt('eeg21o1.csv', delimiter=',', skip_header=0)
d3= genfromtxt('eeg22o1.csv', delimiter=',', skip_header=0)
d4= genfromtxt('eeg23o1.csv', delimiter=',', skip_header=0)
d5= genfromtxt('eeg24o1.csv', delimiter=',', skip_header=0)
d6= genfromtxt('eeg25o1.csv', delimiter=',', skip_header=0)
d7= genfromtxt('eeg27o1.csv', delimiter=',', skip_header=0)
d8= genfromtxt('eeg28o1.csv', delimiter=',', skip_header=0)
d9= genfromtxt('eeg29o1.csv', delimiter=',', skip_header=0)
d10= genfromtxt('eeg32o1.csv', delimiter=',', skip_header=0)
d11= genfromtxt('eeg33o1.csv', delimiter=',', skip_header=0)
d12= genfromtxt('eeg35o1.csv', delimiter=',', skip_header=0)

d1=d1.T
d2=d2.T
d3=d3.T
d4=d4.T
d5=d5.T
d6=d6.T
d7=d7.T
d8=d8.T
d9=d9.T
d10=d10.T
d11=d11.T
d12=d12.T

print("Sample Entropy")
sa1,sa2,sa3,sa4,sa5,sa6,sa7,sa8,sa9,sa10,sa11,sa12=sampl(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12)
print("Renyi Entropy")
r1,r2,r3,r4,r5,r6,r7,r8,r9,r10,r11,r12=renyi_entropy(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12)
print("Permutation Entropy")
p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12=permu(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12)
print("Shanon Entropy")
sh1,sh2,sh3,sh4,sh5,sh6,sh7,sh8,sh9,sh10,sh11,sh12=shan(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12)
print("Energy")
e1,e2,e3,e4,e5,e6,e7,e8,e9,e10,e11,e12=energy(d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12)


x1=[sa1,r1,p1,sh1,e1]
x2=[sa2,r2,p2,sh2,e2]
x3=[sa3,r3,p3,sh3,e3]
x4=[sa4,r4,p4,sh4,e4]
x5=[sa5,r5,p5,sh5,e5]
x6=[sa6,r6,p6,sh6,e6]
x7=[sa7,r7,p7,sh7,e7]
x8=[sa8,r8,p8,sh8,e8]
x9=[sa9,r9,p9,sh9,e9]
x10=[sa10,r10,p10,sh10,e10]
x11=[sa11,r11,p11,sh11,e11]
x12=[sa12,r12,p12,sh12,e12]
X=np.concatenate((x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12),axis=1)

X=np.array(X)
X=X.T
a = np.asarray(X)
print(a.shape)
np.savetxt("AsEntropy Features.csv", a, delimiter=",")
# Out:
# Sample Entropy
# Renyi Entropy
# Permutation Entropy
# Shanon Entropy
# Energy
# (228, 5)

# %%
import pandas as pd
df=pd.read_csv('AEntropy Features.csv',header=None)
df.columns=('SampleEntropy','RenyiEntropy','PermutationEntropy','ShanonEntropy','Energy')
df.to_csv('AEntropy Features.csv',index=False)
