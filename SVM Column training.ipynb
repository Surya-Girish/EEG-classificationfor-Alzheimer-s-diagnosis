# %%
#Splitting the data
from sklearn.model_selection import train_test_split
df = pd.read_csv('ColumnFinal2.csv')
A=df.drop('Label',axis=1)
X_train, X_test, Y_train, Y_test= train_test_split(A, df.Label, test_size=0.3, random_state=19)

# %%
from sklearn.neural_network import MLPClassifier 
import pandas as pd 
from sklearn import preprocessing, metrics 
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score, make_scorer 
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score 
from sklearn.preprocessing import StandardScaler 
import numpy as np

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, Y_train)

#Predict the response for test dataset
Y_pred = clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.7007299270072993

# %%
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(Y_test, Y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(Y_test, Y_pred))
# Out:
# Precision: 0.678082191780822
# Recall: 0.7388059701492538

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
import numpy as np

# cv=10 represents the StratifiedKFold with 10 folds
x1=[]
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred, digits = 2))
    x1.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores1 = cross_val_score(clf, X=X_train, y=Y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores1)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)))
# Out:
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.76      0.50      0.60        32
#            1       0.63      0.84      0.72        32
#
#     accuracy                           0.67        64
#    macro avg       0.69      0.67      0.66        64
# weighted avg       0.69      0.67      0.66        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50        32
#            1       0.58      0.88      0.70        32
#
#     accuracy                           0.62        64
#    macro avg       0.67      0.62      0.60        64
# weighted avg       0.67      0.62      0.60        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.61      0.34      0.44        32
#            1       0.54      0.78      0.64        32
#
# ...

# %%
from sklearn.metrics import confusion_matrix as cm

m1 = cm(Y_test,Y_pred)
m1
# Out:
# array([[93, 47],
#        [35, 99]], dtype=int64)

# %%
#Import scikit-learn dataset library
from sklearn import datasets
import pandas as pd
#Load dataset
df = pd.read_csv('DecompWaveFeatures.csv')

#Splitting the data
from sklearn.model_selection import train_test_split
A=df.drop('Label',axis=1)
X_train, X_test, Y_train, Y_test= train_test_split(A, df.Label, test_size=0.3, random_state=19)

#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, Y_train)

#Predict the response for test dataset
Y_pred = clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(Y_test, Y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(Y_test, Y_pred))

from sklearn.model_selection import cross_val_score, StratifiedKFold
import numpy as np

# cv=10 represents the StratifiedKFold with 10 folds
x2=[]
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred, digits = 2))
    x2.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores2 = cross_val_score(clf, X=X_train, y=Y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores2)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores2),np.std(scores2)))
# Out:
# Accuracy: 0.916058394160584
# Precision: 0.9710144927536232
# Recall: 0.8758169934640523
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        33
#            1       0.87      0.87      0.87        31
#
#     accuracy                           0.88        64
#    macro avg       0.87      0.87      0.87        64
# weighted avg       0.88      0.88      0.88        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89        33
#            1       0.96      0.77      0.86        31
#
#     accuracy                           0.88        64
#    macro avg       0.89      0.87      0.87        64
# weighted avg       0.89      0.88      0.87        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90        33
# ...

# %%
from sklearn.metrics import confusion_matrix as cm

m2 = cm(Y_test,Y_pred)
m2
# Out:
# array([[117,   4],
#        [ 19, 134]], dtype=int64)

# %% [raw]
# #Import scikit-learn dataset library
# from sklearn import datasets
# import pandas as pd
# #Load dataset
# df = pd.read_csv('ColumnFinal2.csv')
#
# #Splitting the data
# from sklearn.model_selection import train_test_split
# A=df.drop('Label',axis=1)
# X_train, X_test, Y_train, Y_test= train_test_split(A, df.Label, test_size=0.3, random_state=19)
#
# #Import svm model
# from sklearn import svm
#
# #Create a svm Classifier
# clf = svm.SVC(kernel='linear') # Linear Kernel
#
# #Train the model using the training sets
# clf.fit(X_train, Y_train)
#
# #Predict the response for test dataset
# Y_pred = clf.predict(X_test)
#
# #Import scikit-learn metrics module for accuracy calculation
# from sklearn import metrics
#
# # Model Accuracy: how often is the classifier correct?
# print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
#
# # Model Precision: what percentage of positive tuples are labeled as such?
# print("Precision:",metrics.precision_score(Y_test, Y_pred))
#
# # Model Recall: what percentage of positive tuples are labelled as such?
# print("Recall:",metrics.recall_score(Y_test, Y_pred))
#
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# import numpy as np
#
# # cv=10 represents the StratifiedKFold with 10 folds
# x3=[]
# def cls_rep(y_true,y_pred):
#
#     print ('\n\nCross validation metrics :\n'
#
#
#            ,classification_report(y_true, y_pred, digits = 2))
#     x3.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
#
#     return accuracy_score(y_true,y_pred)
#
#
# scores3 = cross_val_score(clf, X=X_train, y=Y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))
#
#
# print('Cross Validation scores: %s' % scores3)
#
# print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores3),np.std(scores3)))

# %%
#Import scikit-learn dataset library
from sklearn import datasets
import pandas as pd
#Load dataset
df = pd.read_csv('ColumnFinal2.csv')

#Splitting the data
from sklearn.model_selection import train_test_split
A=df.drop('Label',axis=1)
X_train, X_test, Y_train, Y_test= train_test_split(A, df.Label, test_size=0.3, random_state=19)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, Y_train)

#Predict the response for test dataset
Y_pred = clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(Y_test, Y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(Y_test, Y_pred))

from sklearn.model_selection import cross_val_score, StratifiedKFold
import numpy as np

# cv=10 represents the StratifiedKFold with 10 folds
x3=[]
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred, digits = 2))
    x3.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores3 = cross_val_score(clf, X=X_train, y=Y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores3)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores3),np.std(scores3)))
# Out:
# Accuracy: 0.9708029197080292
# Precision: 0.9801324503311258
# Recall: 0.9673202614379085
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        33
#            1       1.00      0.97      0.98        31
#
#     accuracy                           0.98        64
#    macro avg       0.99      0.98      0.98        64
# weighted avg       0.98      0.98      0.98        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        33
#            1       0.94      1.00      0.97        31
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
# ...

# %%
df=pd.read_csv('CValSet.csv')
A=df.drop('Label',axis=1)



# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=1, random_state=42) # 70% training and 30% test

X_train=scaler.transform(X_train)

scores4 = cross_val_score(clf, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))


 
print('Cross Validation scores: %s' % scores4)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores4),np.std(scores4)))
# Out:
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91        46
#            1       0.98      1.00      0.99       304
#
#     accuracy                           0.98       350
#    macro avg       0.98      0.92      0.95       350
# weighted avg       0.98      0.98      0.98       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88        46
#            1       0.98      0.98      0.98       304
#
#     accuracy                           0.97       350
#    macro avg       0.93      0.93      0.93       350
# weighted avg       0.97      0.97      0.97       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92        46
#            1       0.98      1.00      0.99       304
#
# ...

# %%
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores3),np.std(scores3)))
# Out:
# Cross Validation accuracy: 0.939 +/- 0.026

# %%
from sklearn.metrics import confusion_matrix as cm

m3 = cm(Y_test,Y_pred)
m3

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

ax= plt.subplot()
sns.heatmap(m1, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal1'); 
ax.xaxis.set_ticklabels(['demented', 'healthy']); ax.yaxis.set_ticklabels(['demented', 'healthy']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

ax= plt.subplot()
sns.heatmap(m2, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for DecompWaveFeatures'); 
ax.xaxis.set_ticklabels(['demented', 'healthy']); ax.yaxis.set_ticklabels(['demented', 'healthy']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

ax= plt.subplot()
sns.heatmap(m3, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal2'); 
ax.xaxis.set_ticklabels(['demented', 'healthy']); ax.yaxis.set_ticklabels(['demented', 'healthy']);

# %%
def round_dict(d,k):
    res = dict()
    for key in d:
        res[key]=round(d[key],k)
    return res
        


def parse(d):
    fin = dict()
    i=-1
    k=3
    for key in d:
        i=i+1
        fin[i]=round_dict(key,k)
    fin = pd.DataFrame(fin,index= None)
    return(fin)
 

    
print(x1['0'])
print((parse(x1['0'])))

# %%
x1 = pd.DataFrame(x1,index=None)
x2 = pd.DataFrame(x2, index=None)
x3 = pd.DataFrame(x3, index=None)

f1 = ["Label:0",parse(x1['0']),parse(x2['0']),parse(x3['0'])]
f2 = ["Label:1",parse(x1['1']),parse(x2['1']),parse(x3['1'])]
f3 = ["Accuracy",(x1['accuracy']),(x2['accuracy']),(x3['accuracy'])]
f4 = ["Macro Avg",parse(x1['macro avg']),parse(x2['macro avg']),parse(x3['macro avg'])]
f5 = ["Weighted Avg",parse(x1['weighted avg']),parse(x2['weighted avg']),parse(x3['weighted avg'])]
f6 = ["Avg Accuracy",'%.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)),
      '%.3f +/- %.3f' % (np.mean(scores2),np.std(scores2))
      ,'%.3f +/- %.3f' % (np.mean(scores3),np.std(scores3))]
f = (f1,f2,f3,f4,f5,f6)

f = pd.DataFrame(f, columns = ['Types','Columns','DecomWaves','Column+DecompWaves'], index = None)

print(f.shape)
f.to_csv('SVMColumns.csv',index=None)
