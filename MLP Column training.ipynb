# %%
from sklearn.neural_network import MLPClassifier 
import pandas as pd 
from sklearn import preprocessing, metrics 
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score, make_scorer 
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score 
from sklearn.preprocessing import StandardScaler 
import numpy as np

# %%
df=pd.read_csv('ColumnFinal1.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Initializing the MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu'
                    ,solver='adam',random_state=23)
mlp.fit(X_train,y_train)

y_pred=mlp.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Class Report: ",classification_report(y_test, y_pred, output_dict = True, digits = 2))
print("\n\nAccuracy:", accuracy)

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))

# cv=10 represents the StratifiedKFold with 10 folds
x1=[];
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x1.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores1 = cross_val_score(mlp, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores1)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)))
# Out:
# Class Report:  {'0': {'precision': 0.8251748251748252, 'recall': 0.855072463768116, 'f1-score': 0.8398576512455517, 'support': 138}, '1': {'precision': 0.8473282442748091, 'recall': 0.8161764705882353, 'f1-score': 0.8314606741573033, 'support': 136}, 'accuracy': 0.8357664233576643, 'macro avg': {'precision': 0.8362515347248172, 'recall': 0.8356244671781756, 'f1-score': 0.8356591627014275, 'support': 274}, 'weighted avg': {'precision': 0.8361706828302916, 'recall': 0.8357664233576643, 'f1-score': 0.8356898086032094, 'support': 274}}
#
#
# Accuracy: 0.8357664233576643
# Precision: 0.8473282442748091
# Recall: 0.8161764705882353
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        32
#            1       0.62      0.62      0.62        32
#
#     accuracy                           0.62        64
#    macro avg       0.62      0.62      0.62        64
# weighted avg       0.62      0.62      0.62        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78        32
#            1       0.78      0.78      0.78        32
#
#     accuracy                           0.78        64
#    macro avg       0.78      0.78      0.78        64
# weighted avg       0.78      0.78      0.78        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.76      0.69      0.72        32
#            1       0.71      0.78      0.75        32
#
#     accuracy                           0.73        64
#    macro avg       0.74      0.73      0.73        64
# weighted avg       0.74      0.73      0.73        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82        32
#            1       0.83      0.78      0.81        32
#
#     accuracy                           0.81        64
#    macro avg       0.81      0.81      0.81        64
# weighted avg       0.81      0.81      0.81        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87        32
#            1       0.96      0.75      0.84        32
#
#     accuracy                           0.86        64
#    macro avg       0.88      0.86      0.86        64
# weighted avg       0.88      0.86      0.86        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72        32
#            1       0.72      0.72      0.72        32
#
#     accuracy                           0.72        64
#    macro avg       0.72      0.72      0.72        64
# weighted avg       0.72      0.72      0.72        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.71      0.78      0.75        32
#            1       0.76      0.69      0.72        32
#
#     accuracy                           0.73        64
#    macro avg       0.74      0.73      0.73        64
# weighted avg       0.74      0.73      0.73        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83        32
#            1       0.84      0.81      0.83        32
#
#     accuracy                           0.83        64
#    macro avg       0.83      0.83      0.83        64
# weighted avg       0.83      0.83      0.83        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72        31
#            1       0.73      0.69      0.71        32
#
#     accuracy                           0.71        63
#    macro avg       0.72      0.71      0.71        63
# weighted avg       0.72      0.71      0.71        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89        31
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.89        63
#    macro avg       0.89      0.89      0.89        63
# weighted avg       0.89      0.89      0.89        63
#
# Cross Validation scores: [0.625      0.78125    0.734375   0.8125     0.859375   0.71875
#  0.734375   0.828125   0.71428571 0.88888889]
#
#
# Cross Validation accuracy: 0.770 +/- 0.075

# %%
from sklearn.metrics import confusion_matrix as cm

m1 = cm(y_test,y_pred)
m1
# Out:
# array([[118,  20],
#        [ 25, 111]], dtype=int64)

# %%
import pandas as pd
df = pd.read_csv('ColumnFinal1.csv')
df.shape
# Out:
# (912, 23)

# %%
from sklearn.neural_network import MLPClassifier
import pandas as pd
from sklearn import preprocessing, metrics
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score, make_scorer
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
from sklearn.preprocessing import  StandardScaler
import numpy as np

df=pd.read_csv('DecompWaveFeatures.csv')
x=df.drop('Label',axis=1)
y=df.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#Initializing the MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu'
                    ,solver='adam',random_state=23)
mlp.fit(X_train,y_train)

y_pred=mlp.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Class Report: ",classification_report(y_test, y_pred, output_dict = True, digits = 2))


print("Accuracy:", accuracy)

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))

# cv=10 represents the StratifiedKFold with 10 folds
#
x2=[]
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x2.append(classification_report(y_true, y_pred, output_dict = True, digits = 2))
    
    return accuracy_score(y_true,y_pred)


scores2 = cross_val_score(mlp, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

 
print('Cross Validation scores: %s' % scores2)

 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores2),np.std(scores2)))
# Out:
# Class Report:  {'0': {'precision': 0.9328358208955224, 'recall': 0.9124087591240876, 'f1-score': 0.922509225092251, 'support': 137}, '1': {'precision': 0.9142857142857143, 'recall': 0.9343065693430657, 'f1-score': 0.9241877256317689, 'support': 137}, 'accuracy': 0.9233576642335767, 'macro avg': {'precision': 0.9235607675906183, 'recall': 0.9233576642335766, 'f1-score': 0.9233484753620099, 'support': 274}, 'weighted avg': {'precision': 0.9235607675906183, 'recall': 0.9233576642335767, 'f1-score': 0.92334847536201, 'support': 274}}
# Accuracy: 0.9233576642335767
# Precision: 0.9142857142857143
# Recall: 0.9343065693430657
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        32
#            1       0.94      1.00      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        32
#            1       0.97      1.00      0.98        32
#
#     accuracy                           0.98        64
#    macro avg       0.98      0.98      0.98        64
# weighted avg       0.98      0.98      0.98        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92        32
#            1       0.94      0.91      0.92        32
#
#     accuracy                           0.92        64
#    macro avg       0.92      0.92      0.92        64
# weighted avg       0.92      0.92      0.92        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91        32
#            1       0.96      0.84      0.90        32
#
#     accuracy                           0.91        64
#    macro avg       0.91      0.91      0.91        64
# weighted avg       0.91      0.91      0.91        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94        32
#            1       0.91      0.97      0.94        32
#
#     accuracy                           0.94        64
#    macro avg       0.94      0.94      0.94        64
# weighted avg       0.94      0.94      0.94        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95        32
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.95        64
#    macro avg       0.95      0.95      0.95        64
# weighted avg       0.95      0.95      0.95        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        32
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        32
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95        31
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.95        63
#    macro avg       0.95      0.95      0.95        63
# weighted avg       0.95      0.95      0.95        63
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        32
#            1       0.97      0.94      0.95        31
#
#     accuracy                           0.95        63
#    macro avg       0.95      0.95      0.95        63
# weighted avg       0.95      0.95      0.95        63
#
# Cross Validation scores: [0.96875    0.984375   0.921875   0.90625    0.9375     0.953125
#  1.         0.96875    0.95238095 0.95238095]
#
#
# Cross Validation accuracy: 0.955 +/- 0.027

# %%
from sklearn.metrics import confusion_matrix as cm

m2 = cm(y_test,y_pred)
m2
# Out:
# array([[125,  12],
#        [  9, 128]], dtype=int64)

# %%
from sklearn.neural_network import MLPClassifier
import pandas as pd
from sklearn import preprocessing, metrics
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
from sklearn.preprocessing import  StandardScaler
import numpy as np

df=pd.read_csv('ColumnFinal2.csv')
df2 = pd.read_csv('Trial.csv')
x=df.drop('Label',axis=1)
y=df.Label
a = df2.drop('Label',axis=1)
b = df2.Label
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=4)
a, c, b, d = train_test_split(a,b, test_size=0.3, random_state=42)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
a = scaler.transform(a)

#Initializing the MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu'
                    ,solver='adam',random_state=23)
mlp.fit(X_train,y_train)

y_pred=mlp.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Class Report: ",classification_report(y_test, y_pred, output_dict = True, digits = 2 ))
print("\n\nAccuracy:", accuracy)

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))

x3=[];

# cv=10 represents the StratifiedKFold with 10 folds
def cls_rep(y_true,y_pred):
    
    print ('\n\nCross validation metrics :\n'
           
           
           ,classification_report(y_true, y_pred))
    x3.append(classification_report(y_true, y_pred, output_dict = True, digits = 2 ))
    
    return accuracy_score(y_true,y_pred)


scores3 = cross_val_score(mlp, X=a, y=b, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))

print(X_train)
 
print('Cross Validation scores: %s' % scores3)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores3),np.std(scores3)))
# Out:
# Class Report:  {'0': {'precision': 0.9565217391304348, 'recall': 0.9635036496350365, 'f1-score': 0.9600000000000001, 'support': 137}, '1': {'precision': 0.9632352941176471, 'recall': 0.9562043795620438, 'f1-score': 0.9597069597069599, 'support': 137}, 'accuracy': 0.9598540145985401, 'macro avg': {'precision': 0.9598785166240409, 'recall': 0.9598540145985401, 'f1-score': 0.9598534798534799, 'support': 274}, 'weighted avg': {'precision': 0.9598785166240408, 'recall': 0.9598540145985401, 'f1-score': 0.95985347985348, 'support': 274}}
#
#
# Accuracy: 0.9598540145985401
# Precision: 0.9632352941176471
# Recall: 0.9562043795620438
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        16
#            1       1.00      0.94      0.97        16
#
#     accuracy                           0.97        32
#    macro avg       0.97      0.97      0.97        32
# weighted avg       0.97      0.97      0.97        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        16
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        16
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        16
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        16
#            1       0.94      0.94      0.94        16
#
#     accuracy                           0.94        32
#    macro avg       0.94      0.94      0.94        32
# weighted avg       0.94      0.94      0.94        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        17
#            1       0.88      1.00      0.94        15
#
#     accuracy                           0.94        32
#    macro avg       0.94      0.94      0.94        32
# weighted avg       0.94      0.94      0.94        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      1.00      1.00        15
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      1.00      1.00        15
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      1.00      1.00        15
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        16
#            1       0.94      1.00      0.97        15
#
#     accuracy                           0.97        31
#    macro avg       0.97      0.97      0.97        31
# weighted avg       0.97      0.97      0.97        31
#
# [[-0.27644052 -1.27798453 -0.27637732 ...  0.2345629   0.
#   -0.09945409]
#  [-0.4041857  -0.95607749 -0.37876369 ... -0.97445079  0.
#   -0.29500674]
#  [-0.60929188 -0.1049059   0.0331288  ...  0.21175425  0.
#   -0.14780638]
#  ...
#  [-0.32221607  1.3139476  -0.4643095  ...  0.44045394  0.
#   -0.1779653 ]
#  [ 0.83149426 -0.50812794 -0.38454065 ...  1.35822952  0.
#   -0.25547464]
#  [-0.99429137  0.03220031 -0.47107983 ... -0.74047682  0.
#   -0.00797783]]
# Cross Validation scores: [0.96875    1.         1.         1.         0.9375     0.9375
#  1.         1.         1.         0.96774194]
#
#
# Cross Validation accuracy: 0.981 +/- 0.025

# %%
df=pd.read_csv('CValSet.csv')
A=df.drop('Label',axis=1)



# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(A, df.Label, test_size=1, random_state=42) # 70% training and 30% test

X_train=scaler.transform(X_train)

scores4 = cross_val_score(mlp, X=X_train, y=y_train, cv=10, n_jobs=1, scoring = make_scorer(cls_rep))


 
print('Cross Validation scores: %s' % scores4)
 
print('\n\nCross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores4),np.std(scores4)))
# Out:
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97        46
#            1       0.99      1.00      1.00       304
#
#     accuracy                           0.99       350
#    macro avg       1.00      0.97      0.98       350
# weighted avg       0.99      0.99      0.99       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        46
#            1       0.99      1.00      1.00       304
#
#     accuracy                           0.99       350
#    macro avg       0.99      0.98      0.98       350
# weighted avg       0.99      0.99      0.99       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        46
#            1       1.00      1.00      1.00       304
#
#     accuracy                           1.00       350
#    macro avg       1.00      0.99      0.99       350
# weighted avg       1.00      1.00      1.00       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        46
#            1       0.99      1.00      1.00       304
#
#     accuracy                           0.99       350
#    macro avg       1.00      0.98      0.99       350
# weighted avg       0.99      0.99      0.99       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        46
#            1       1.00      1.00      1.00       304
#
#     accuracy                           1.00       350
#    macro avg       0.99      1.00      0.99       350
# weighted avg       1.00      1.00      1.00       350
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        46
#            1       0.99      1.00      1.00       303
#
#     accuracy                           0.99       349
#    macro avg       1.00      0.98      0.99       349
# weighted avg       0.99      0.99      0.99       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        45
#            1       1.00      1.00      1.00       304
#
#     accuracy                           0.99       349
#    macro avg       0.99      0.99      0.99       349
# weighted avg       0.99      0.99      0.99       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        45
#            1       0.99      1.00      1.00       304
#
#     accuracy                           0.99       349
#    macro avg       1.00      0.98      0.99       349
# weighted avg       0.99      0.99      0.99       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        45
#            1       1.00      1.00      1.00       304
#
#     accuracy                           1.00       349
#    macro avg       1.00      0.99      0.99       349
# weighted avg       1.00      1.00      1.00       349
#
#
#
# Cross validation metrics :
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        45
#            1       1.00      0.99      1.00       304
#
#     accuracy                           0.99       349
#    macro avg       0.98      0.99      0.98       349
# weighted avg       0.99      0.99      0.99       349
#
# Cross Validation scores: [0.99142857 0.99142857 0.99714286 0.99428571 0.99714286 0.99426934
#  0.99426934 0.99426934 0.99713467 0.99140401]
#
#
# Cross Validation accuracy: 0.994 +/- 0.002

# %%
from sklearn.metrics import confusion_matrix as cm

m3 = cm(y_test,y_pred)
m3
# Out:
# array([[132,   5],
#        [  6, 131]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m1, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal1'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


ax= plt.subplot()
sns.heatmap(m2, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for DecompWaveFeatures'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

unique, counts = np.unique(y_pred, return_counts=True)
print(unique)
print(counts)

ax= plt.subplot()
sns.heatmap(m3, annot=True, fmt='g', ax=ax); 
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix for ColumnFinal2'); 
ax.xaxis.set_ticklabels(['Healthy', 'Demented']); ax.yaxis.set_ticklabels(['Healthy', 'Demented']);
# Out:
# [0 1]
# [138 136]

# %%
x1=pd.DataFrame(x1,index=None)
print(x1.T[1]['0'])
# Out:
# {'precision': 0.78125, 'recall': 0.78125, 'f1-score': 0.78125, 'support': 32}

# %%
def round_dict(d,k):
    res = dict()
    for key in d:
        res[key]=round(d[key],k)
    return res
        


def parse(d):
    fin = dict()
    i=-1
    k=3
    for key in d:
        i=i+1
        fin[i]=round_dict(key,k)
    fin = pd.DataFrame(fin,index= None)
    return(fin)
 

    
print(x1['0'])
print((parse(x1['0'])))
# Out:
# 0    {'precision': 0.625, 'recall': 0.625, 'f1-scor...
# 1    {'precision': 0.78125, 'recall': 0.78125, 'f1-...
# 2    {'precision': 0.7586206896551724, 'recall': 0....
# 3    {'precision': 0.7941176470588235, 'recall': 0....
# 4    {'precision': 0.7948717948717948, 'recall': 0....
# 5    {'precision': 0.71875, 'recall': 0.71875, 'f1-...
# 6    {'precision': 0.7142857142857143, 'recall': 0....
# 7    {'precision': 0.8181818181818182, 'recall': 0....
# 8    {'precision': 0.696969696969697, 'recall': 0.7...
# 9    {'precision': 0.9, 'recall': 0.870967741935483...
# Name: 0, dtype: object
#                 0       1       2       3       4       5       6       7  \
# precision   0.625   0.781   0.759   0.794   0.795   0.719   0.714   0.818
# recall      0.625   0.781   0.688   0.844   0.969   0.719   0.781   0.844
# f1-score    0.625   0.781   0.721   0.818   0.873   0.719   0.746   0.831
# support    32.000  32.000  32.000  32.000  32.000  32.000  32.000  32.000
#
#                 8       9
# precision   0.697   0.900
# recall      0.742   0.871
# f1-score    0.719   0.885
# support    31.000  31.000

# %%
x1 = pd.DataFrame(x1,index=None)
x2 = pd.DataFrame(x2, index=None)
x3 = pd.DataFrame(x3, index=None)

f1 = ["Label:0",parse(x1['0']),parse(x2['0']),parse(x3['0'])]
f2 = ["Label:1",parse(x1['1']),parse(x2['1']),parse(x3['1'])]
f3 = ["Accuracy",(x1['accuracy']),(x2['accuracy']),(x3['accuracy'])]
f4 = ["Macro Avg",parse(x1['macro avg']),parse(x2['macro avg']),parse(x3['macro avg'])]
f5 = ["Weighted Avg",parse(x1['weighted avg']),parse(x2['weighted avg']),parse(x3['weighted avg'])]
f6 = ["Avg Accuracy",'%.3f +/- %.3f' % (np.mean(scores1),np.std(scores1)),
      '%.3f +/- %.3f' % (np.mean(scores2),np.std(scores2))
      ,'%.3f +/- %.3f' % (np.mean(scores3),np.std(scores3))]
f = (f1,f2,f3,f4,f5,f6)

f = pd.DataFrame(f, columns = ['Types','Columns','DecomWaves','Column+DecompWaves'], index = None)

print(f.shape)
f.to_csv('MLPColumns.csv',index=None)
# Out:
# (6, 4)
